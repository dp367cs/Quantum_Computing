# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

# %%
qc = QuantumCircuit(2, 2)

# %%
qc.h(0)

# %%
qc.cx(0, 1)

# %%
qc.measure([0, 1], [0, 1])

# %%
qc.draw('mpl')

# %%
backend = Aer.get_backend('qasm_simulator')

# %%
job = execute(qc, backend, shots=1024)
result = job.result()

# %%
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# ## Code to Test Circuit Identities

# %%
qc = QuantumCircuit(1)

# %%
qc.h(0)
qc.x(0)
qc.h(0)

# %%
qc.measure_all()

# %%
job = execute(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts()
print(counts)
# Out:
# {'0': 1024}

# %% [markdown]
# ## Code to Generate All Four Bell States

# %%
def create_bell_state(state):
    qc = QuantumCircuit(2, 2)

# %%
qc.h(0)

# %%
from qiskit import QuantumCircuit #from chatgpt

qc = QuantumCircuit(2)  # Ensure at least 2 qubits
qc.cx(0, 1)  # Apply CNOT gate
qc.draw('mpl')  # Visualize the circuit

# %%
    qc.cx(0, 1)

# %%
def check_state(state):  #from chatgpt
    if state == "Φ+":
        print("Bell state Φ+")
    elif state == "Ψ+":
        print("Bell state Ψ+")
    else:
        print("Unknown state")

# %%
qc = QuantumCircuit(2, 2)  # 2 qubits, 2 classical bits
qc.measure([0, 1], [0, 1])  # Now it works!
qc.draw('mpl')  # Optional: visualize the circuit

# %%
 qc.measure([0, 1], [0, 1])
 qc

# %%
def create_bell_state(state):
    qc = QuantumCircuit(2, 2)  # 2 qubits, 2 classical bits
    qc.h(0)
    qc.cx(0, 1)
    qc.measure([0, 1], [0, 1])
    return qc  # ✅ Ensure the function returns qc

# %%
bell_states = ["Φ+", "Φ-", "Ψ+", "Ψ-"]
for state in bell_states:
    qc = create_bell_state(state)
    print(f"Circuit for {state}:")
    display(qc.draw('mpl'))
# Out:
# Circuit for Φ+:
# Circuit for Φ-:
# Circuit for Ψ+:
# Circuit for Ψ-:

# %%
backend = Aer.get_backend('qasm_simulator')

# %%
    qc = create_bell_state(state)
    job = execute(qc, backend, shots=1024)
    result = job.result()

# %%
    counts = result.get_counts()
    print(f"Results for {state}:")
    display(plot_histogram(counts))
# Out:
# Results for Ψ-:
